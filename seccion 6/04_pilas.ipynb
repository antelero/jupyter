# %%
apilar = [1,2,3,4]
apilar
# Out:
# [1, 2, 3, 4]

# %%
apilar.append(6)
apilar.append(7)
apilar.append(8)

# %%
apilar
# Out:
# [1, 2, 3, 4, 6, 7, 8]

# %%
apilar.pop()
apilar
# Out:
# [1, 2, 3, 4, 6, 7]

# %%
print(apilar)
no_perderlo = apilar.pop()
print(no_perderlo)
print(apilar)
# Out:
# [1, 6, 7, 8]
# 8
# [1, 6, 7]
