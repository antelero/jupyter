# %%
t=('leo','feli','flor',10,[1,2,3],-8)
t
# Out:
# ('leo', 'feli', 'flor', 10, [1, 2, 3], -8)

# %%
t[0]
# Out:
# 'leo'

# %%
t[4]
# Out:
# [1, 2, 3]

# %%
t[0] = 'nadie'
t
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-d7681df2dc6d> in <module>
# ----> 1 t[0] = 'nadie'
#       2 t
#
# TypeError: 'tuple' object does not support item assignment

# %%
len(t)
# Out:
# 6

# %%
len(t[4])
# Out:
# 3

# %%
t.index('leo')
# Out:
# 0

# %%
t.index('nadie')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-16cfc12ae3c7> in <module>
# ----> 1 t.index('nadie')
#
# ValueError: tuple.index(x): x not in tuple

# %%
t.count(10)
# Out:
# 1

# %%
t.count('nadie')
# Out:
# 0

# %%
t.append(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-7bc26d8122b5> in <module>
# ----> 1 t.append(5)
#
# AttributeError: 'tuple' object has no attribute 'append'
