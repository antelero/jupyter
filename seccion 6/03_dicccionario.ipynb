# %%
dicc = {'leonardo':'brambilla','silvina':'brambilla','felipe':'brambilla maldonado'}
dicc
# Out:
# {'leonardo': 'brambilla',
#  'silvina': 'brambilla',
#  'felipe': 'brambilla maldonado'}

# %%
type(dicc)
# Out:
# dict

# %%
dicc['leonardo']
# Out:
# 'brambilla'

# %%
dicc['leonardo']='profesor'

# %%
dicc

# %%
del(dicc['leonardo'])

# %%
dicc
# Out:
# {'silvina': 'brambilla', 'felipe': 'brambilla maldonado'}

# %%
edades = {'estudiante':20, 'otros':30}

# %%
edades ['estudiante']+=1
edades
# Out:
# {'estudiante': 2, 'otros': 30}

# %%
edades ['estudiante'] + edades  ['otros']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-a0a8a5545cde> in <module>
#       1 edades
# ----> 2 ['estudiante'] + edades  ['otros']
#
# TypeError: can only concatenate list (not "int") to list

# %%
for edad in edades:
    print(edades)
# Out:
# {'estudiante': 2, 'otros': 30}
# {'estudiante': 2, 'otros': 30}

# %%
for edad in edades:
    print(edad,edades[edad])
# Out:
# estudiante 2
# otros 30

# %%
lista = []
lista.append(edades)
lista
# Out:
# [{'estudiante': 2, 'otros': 30}]

# %%
edades = {'estudiante nuevo':20, 'otros talvez':30}
lista.append(edades)
lista
# Out:
# [{'estudiante': 2, 'otros': 30}, {'estudiante nuevo': 20, 'otros talvez': 30}]
