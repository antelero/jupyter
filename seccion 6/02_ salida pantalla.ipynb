# %%
print('hola gentes')

# %%
variable = 'Leonardo Brambilla'
otra = 'genios estudiantes'

# %%
forma = "El profesor '{}' y sus '{}'".format(variable,otra)
forma

# %%
print(forma)

# %%
forma = "El profesor '{1}' y sus '{0}'".format(variable,otra)
forma

# %%
print('{:10}'.format('Leonardo Brambilla'))
print('{:>10}'.format('Leonardo Brambilla'))
