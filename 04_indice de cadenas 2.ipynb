# %%
variable = "Leonardo Brambilla"
variable
# Out:
# 'Leonardo Brambilla'

# %%
import numpy
print(numpy.__version__)
numpy.random.randn()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-b6754619db1d> in <module>
# ----> 1 import numpy
#       2 print(numpy.__version__)
#       3 numpy.random.randn()
#
# ModuleNotFoundError: No module named 'numpy'

# %%
1+1
# Out:
# 2

# %%
variable[9]
# Out:
# 'B'

# %%
variable[-5]
# Out:
# 'b'

# %%
variable[0:5]
# Out:
# 'Leona'

# %%
variable[:5]
# Out:
# 'Leona'

# %%
variable[9:]
# Out:
# 'Brambilla'

# %%
len(variable)
# Out:
# 18
