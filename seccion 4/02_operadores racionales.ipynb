# %%
1 != 2
# Out:
# True

# %%
4>=4
# Out:
# True

# %%
4>4
# Out:
# False

# %%
alvaro = 20
chirou = 5

# %%
alvaro > chirou
# Out:
# True

# %%
alvaro != chirou
# Out:
# True

# %%
alvaro ==chirou
# Out:
# False

# %%
listaa= [3,4,5]
listab= [3,4,5]

# %%
listaa ==listab
# Out:
# True
