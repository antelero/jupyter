# %%
2+2 == 4
# Out:
# True

# %%
2+4 == 4
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False == True
# Out:
# True

# %%
False  and False
# Out:
# False

# %%
True and True
# Out:
# True

# %% [raw]
# numero = 10
# numero > 5 and numero < 15

# %%
numero = 10
numero < 5 and numero > 15
# Out:
# False

# %%
numero > 5 or numero < 15
# Out:
# True

# %%
palabra = "Leo"

# %%
palabra == "salir"
