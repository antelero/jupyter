# %%
primero = 8
segundo = 10

# %%
primero * segundo - 4**primero or not (primero % segundo )==0
# Out:
# -65456

# %%
primero * segundo - 4**primero <= 0 or not (primero % segundo )==0
# Out:
# True

# %%
valor = 10

# %%
valor += 10

# %%
valor
# Out:
# 20

# %%
valor -=10

# %%
valor
# Out:
# 10

# %%
valor *=10

# %%
valor
# Out:
# 100

# %%
valor /=10

# %%
valor
# Out:
# 10.0

# %%
valor **=10

# %%
valor
# Out:
# 10000000000.0

# %%
valor %=10

# %%
valor
# Out:
# 0.0
