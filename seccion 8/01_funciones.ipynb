# %%
def saluda():
    print('hola gente')

# %%
saluda()

# %%
def tabladel7():
    for i in range(10):
        print("7 x {i} = {}".format(i, i*7))

tabladel7()

# %%
def advierto():
    global variable = "xyz"
    print(variable)

variable = "zyx"
advierto()
print(variable)
