# %%
def estudiantes():
    return "son genios"
estudiante()

# %%
print(estudiante())

# %%
def estudiante()
    return [4,5,6,7]
print(estudiante())
print(estudiante()[0:2])

# %%
def estudiante()
    return "leonardo brambilla","estudiantes",10,[4,5,6,7]

# %%
estudiante()

# %%
a,b,c,d = estudiante()

# %%
a
b
c
d

# %%
def multiplicacion(i,x):
    return i*x
multiplicacion(5,5)

mult = multiplicacion(5,5)
