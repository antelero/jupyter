# %%
if True:
    print("vammooooo")
# Out:
# vammooooo

# %%
if False:
    print("vammooooo")

# %%
vari = 10

# %%
if vari == 60:
    print(10)

# %%
if vari == 60:
    print(10)
else:
    print("Otro valor")
# Out:
# Otro valor

# %%
if vari == 10:
    if vari == 10:
        print("Otro valor")
else:
    print("Otro valor")
# Out:
# Otro valor
