# %%
i = 1
while i<=3:    
    print('iterando en ',i )
    i+=1
# Out:
# iterando en  1
# iterando en  2
# iterando en  3

# %%
i = 1
while i<=3:    
    print('iterando en ',i )
    i+=1
else:
     print('temino ',i )
# Out:
# iterando en  1
# iterando en  2
# iterando en  3
# temino  4

# %%
i = 1
while i<=3:    
    print('iterando en ',i )
    i+=1
    break
else:
     print('temino ',i )
# Out:
# iterando en  1

# %%
i = 0
while i<=10:   
    if i==4:
        print('iterando en ',i )
        break
    i+=1
    
else:
     print('temino ',i )
# Out:
# iterando en  4

# %%
i = 0
while i<=10:   
    if i==4:
        print('iterando en ',i )
       
    i+=1
    
else:
     print('temino ',i )
# Out:
# iterando en  4
# temino  11
