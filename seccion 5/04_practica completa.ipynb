# %%
print('elige tu propio camino')
inicio = input('Escribe inicio')
while inicio == 'empezar':
    print(""" Camino?
        1-Saludo
        2-Multiplicar
        3-Salir""")
    opcion = input()
    if opcion == '1':
        print('Hola')
    elif opcion == '2':
        nro1 = float(input('valora'))
        nro2 = float(input('valorb'))
        print('Resultado es ', nro1*nro2 )
    elif opcion == '3':
        print('Good Show')
        break
    else: 
        print('opcion incorrecta')
