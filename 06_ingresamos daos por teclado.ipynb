# %%
input()
# Out:
# alvaro
# 'alvaro'

# %%
dato = input()
# Out:
# Leo Brambilla

# %%
dato
# Out:
# 'Leo Brambilla'

# %%
dato + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-32c5e2662bae> in <module>
# ----> 1 dato + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
dato =5

# %%
dato = int(dato)

# %%
dato + 5
# Out:
# 10

# %%
dato = input(
)
# Out:
# 5.5

# %%
dato
# Out:
# '5.5'

# %%
dato = float(dato)
dato
# Out:
# 5.5

# %%
dato + 0.5
# Out:
# 6.0

# %%
dato = float(input("introduzca un numero decimal o entero: "))
# Out:
# introduzca un numero decimal o entero: 3.14

# %%
dato
# Out:
# 3.14
